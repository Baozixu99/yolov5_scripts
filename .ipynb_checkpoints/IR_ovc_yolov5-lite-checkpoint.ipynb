# %%
import torch
import torchvision
from openvino import Core, Type, Tensor
from openvino.runtime import PartialShape, Layout
from openvino.preprocess import PrePostProcessor, ColorFormat
import cv2
import numpy as np
import time
import os
import statistics  # 统计模块
# Out:
# /usr/lib/python3.10/importlib/util.py:247: DeprecationWarning: The `openvino.runtime` module is deprecated and will be removed in the 2026.0 release. Please replace `openvino.runtime` with `openvino`.
#   self.__spec__.loader.exec_module(self)

# %%
def load_labels(label_path):
    """读取标签文件并返回类别ID集合"""
    true_classes = set()
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f.readlines():
                parts = line.strip().split()
                if len(parts) > 0:  # 处理空行
                    class_id = int(parts[0])
                    true_classes.add(class_id)
    return true_classes

def calculate_accuracy(pred_classes, true_classes):
    """计算单张图片的预测准确率"""
    if not true_classes:  # 无标签情况处理
        return 0.0 if pred_classes else 1.0
    
    if not pred_classes:  # 无预测情况处理
        return 0.0
    
    # 计算匹配的类别数
    correct = len(pred_classes & true_classes)
    # 计算准确率（预测类别与真实类别交集的比例）
    return correct / len(true_classes)

# %%
def Inference(compiled_model, image_file):
    #返回预测结果和推理耗时（毫秒）
    start_time = time.perf_counter()
    
    # 读取图像并预处理
    img0 = cv2.imread(image_file)
    print("Original Image Size:", img0.shape)
    
    # 获取模型输入要求
    input_tensor = compiled_model.input(0)
    input_shape = input_tensor.shape  # 应为 [1,256,256,3]
    h, w = input_shape[1], input_shape[2]  # 高度和宽度
    
    # 预处理流程（生成 NHWC 格式）
    img = cv2.resize(img0, (w, h))          # 调整尺寸至 (256,256)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # 转换为 RGB，形状 (256,256,3)
    img = np.expand_dims(img, axis=0)       # 添加批次维度，形状 (1,256,256,3)
    img = img.astype(np.float32) / 255.0    # 归一化
    
    # 创建 OpenVINO Tensor
    input_tensor = Tensor(img)
    
    # 执行推理
    infer_request = compiled_model.create_infer_request()
    infer_request.infer(inputs={0: input_tensor})
    
    # 获取输出
    output_tensor = infer_request.get_output_tensor()
    
    # 计算耗时（毫秒）
    inference_time = (time.perf_counter() - start_time) * 1000
    
    return torch.from_numpy(output_tensor.data), inference_time

# %%
def xywh2xyxy(x):
    # Convert nx4 boxes from [x, y, w, h] to [x1, y1, x2, y2] where xy1=top-left, xy2=bottom-right
    y = x.clone() if isinstance(x, torch.Tensor) else np.copy(x)
    y[:, 0] = x[:, 0] - x[:, 2] / 2  # top left x
    y[:, 1] = x[:, 1] - x[:, 3] / 2  # top left y
    y[:, 2] = x[:, 0] + x[:, 2] / 2  # bottom right x
    y[:, 3] = x[:, 1] + x[:, 3] / 2  # bottom right y
    return y

def non_max_suppression(prediction, conf_thres=0.25, iou_thres=0.45, classes=None, agnostic=False, multi_label=False,
                        labels=(), max_det=300):
    """Runs Non-Maximum Suppression (NMS) on inference results

    Returns:
         list of detections, on (n,6) tensor per image [xyxy, conf, cls]
    """

    nc = prediction.shape[2] - 5  # number of classes
    xc = prediction[..., 4] > conf_thres  # candidates

    # Checks
    assert 0 <= conf_thres <= 1, f'Invalid Confidence threshold {conf_thres}, valid values are between 0.0 and 1.0'
    assert 0 <= iou_thres <= 1, f'Invalid IoU {iou_thres}, valid values are between 0.0 and 1.0'

    # Settings
    min_wh, max_wh = 2, 4096  # (pixels) minimum and maximum box width and height
    max_nms = 30000  # maximum number of boxes into torchvision.ops.nms()
    time_limit = 10.0  # seconds to quit after
    redundant = True  # require redundant detections
    multi_label &= nc > 1  # multiple labels per box (adds 0.5ms/img)
    merge = False  # use merge-NMS

    t = time.time()
    output = [torch.zeros((0, 6), device=prediction.device)] * prediction.shape[0]
    for xi, x in enumerate(prediction):  # image index, image inference
        # Apply constraints
        # x[((x[..., 2:4] < min_wh) | (x[..., 2:4] > max_wh)).any(1), 4] = 0  # width-height
        x = x[xc[xi]]  # confidence
        print("---x shape---:", x.shape)
        # Cat apriori labels if autolabelling
        if labels and len(labels[xi]):
            l = labels[xi]
            v = torch.zeros((len(l), nc + 5), device=x.device)
            v[:, :4] = l[:, 1:5]  # box
            v[:, 4] = 1.0  # conf
            v[range(len(l)), l[:, 0].long() + 5] = 1.0  # cls
            x = torch.cat((x, v), 0)

        # If none remain process next image
        if not x.shape[0]:
            continue

        # Compute conf
        x[:, 5:] *= x[:, 4:5]  # conf = obj_conf * cls_conf

        # Box (center x, center y, width, height) to (x1, y1, x2, y2)
        box = xywh2xyxy(x[:, :4])

        # Detections matrix nx6 (xyxy, conf, cls)
        if multi_label:
            i, j = (x[:, 5:] > conf_thres).nonzero(as_tuple=False).T
            x = torch.cat((box[i], x[i, j + 5, None], j[:, None].float()), 1)
        else:  # best class only
            conf, j = x[:, 5:].max(1, keepdim=True)
            x = torch.cat((box, conf, j.float()), 1)[conf.view(-1) > conf_thres]

        # Filter by class
        if classes is not None:
            x = x[(x[:, 5:6] == torch.tensor(classes, device=x.device)).any(1)]

        # Apply finite constraint
        # if not torch.isfinite(x).all():
        #     x = x[torch.isfinite(x).all(1)]

        # Check shape
        n = x.shape[0]  # number of boxes
        if not n:  # no boxes
            continue
        elif n > max_nms:  # excess boxes
            x = x[x[:, 4].argsort(descending=True)[:max_nms]]  # sort by confidence

        # Batched NMS
        c = x[:, 5:6] * (0 if agnostic else max_wh)  # classes
        boxes, scores = x[:, :4] + c, x[:, 4]  # boxes (offset by class), scores
        i = torchvision.ops.nms(boxes, scores, iou_thres)  # NMS
        if i.shape[0] > max_det:  # limit detections
            i = i[:max_det]
        if merge and (1 < n < 3E3):  # Merge NMS (boxes merged using weighted mean)
            # update boxes as boxes(i,4) = weights(i,n) * boxes(n,4)
            iou = box_iou(boxes[i], boxes) > iou_thres  # iou matrix
            weights = iou * scores[None]  # box weights
            x[i, :4] = torch.mm(weights, x[:, :4]).float() / weights.sum(1, keepdim=True)  # merged boxes
            if redundant:
                i = i[iou.sum(1) > 1]  # require redundancy

        output[xi] = x[i]
        if (time.time() - t) > time_limit:
            print(f'WARNING: NMS time limit {time_limit}s exceeded')
            break  # time limit exceeded

    return output

# %%
# ------------------------- 主程序重构 -------------------------
if __name__ == "__main__":
    # 配置参数
    # 2025推荐使用统一设备API，支持"AUTO", "GPU", "MYRIAD"等
    #DEVICE = "GPU"  
    DEVICE = "AUTO"
    MODEL_XML = '/home/bousew/jupyterWorkspace/is2ros_yolov5_inference/yolov5_scripts/IR_models/IR_model_with_ovc/best.xml'
    MODEL_BIN = '/home/bousew/jupyterWorkspace/is2ros_yolov5_inference/yolov5_scripts/IR_models/IR_model_with_ovc/best.bin'
    IMAGE_DIR = '/home/bousew/jupyterWorkspace/is2ros_yolov5_inference/labels_and_dataset/dataset/fire_smoke/train/images'
    LABELS_DIR = '/home/bousew/jupyterWorkspace/is2ros_yolov5_inference/labels_and_dataset/dataset/fire_smoke/train/labels'
    
    # 初始化OpenVINO Core
    core = Core()
    
    # 加载模型（自动处理xml+bin）
    print("Loading model...")
    model = core.read_model(MODEL_XML)
    
    # 动态输入配置（示例）
    if model.inputs[0].partial_shape.is_dynamic:
        model.reshape({0: PartialShape([1,3,640,640])})
    
    # 预处理配置（可选）
    ppp = PrePostProcessor(model)
    ppp.input().tensor() \
        .set_layout(Layout("NHWC")) \
        .set_color_format(ColorFormat.RGB) \
        .set_element_type(Type.f32)
     # 模型内部布局（如需要可设为 NCHW）
    ppp.input().preprocess() \
        .convert_layout("NCHW") \
        .mean([0.485, 0.456, 0.406]) \
        .scale([0.229, 0.224, 0.225])
    model = ppp.build()
    
    # 编译模型（自动设备发现）
    compiled_model = core.compile_model(model, DEVICE)
    
    # 打印输入输出信息
    print(f"Input shape: {compiled_model.input(0).shape}")
    print(f"Output shape: {compiled_model.output(0).shape}")
    # 初始化统计量
    total_images = 0
    total_correct = 0
    total_predictions = 0

    # 时间统计量
    time_records = []
    total_start = time.perf_counter()
    
    # 执行推理
    print("Starting inference and accuracy calculation...")
    
    pic_list = os.listdir(IMAGE_DIR)
    for pic in pic_list:
        if not pic.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue
        
        # 执行推理并获取耗时
        image_path = os.path.join(IMAGE_DIR, pic)
        prediction, elapsed_time = Inference(compiled_model, image_path)
        time_records.append(elapsed_time)
        
        # 后处理
        print(f"Prediction shape: {prediction.shape}")
        ans = non_max_suppression(prediction, 
                                conf_thres=0.25, 
                                iou_thres=0.45,
                                max_det=300)
        #cls_ids = ans[0][:,-1].unique()
        #print(f"{pic} detected classes: {cls_ids}")
        pred_classes = set(ans[0][:,-1].int().tolist())
        
        # 读取标签
        base_name = os.path.splitext(pic)[0]
        label_path = os.path.join(LABELS_DIR, f"{base_name}.txt")
        true_classes = load_labels(label_path)

        # 统计准确率
        accuracy = calculate_accuracy(pred_classes, true_classes)
        total_images += 1
        total_predictions += len(pred_classes)
        total_correct += len(pred_classes) * accuracy

        # 打印单张图片推理准确率和推理耗时
        print(f"{pic}")
        print(f"  Inference Time: {elapsed_time:.2f}ms")
        print(f"  Predicted: {pred_classes} | True: {true_classes}")
        print(f"  Image Accuracy: {accuracy:.2%}")

    # 总耗时统计
    total_time = (time.perf_counter() - total_start) * 1000  # 转换为毫秒

    # 输出时间统计报告
    print("\nTime Statistics:")
    print(f"Total Images Processed: {len(time_records)}")
    print(f"Total Inference Time: {total_time:.2f}ms")
    print(f"Average Time per Image: {statistics.mean(time_records):.2f}ms")
    print(f"Fastest Inference: {min(time_records):.2f}ms")
    print(f"Slowest Inference: {max(time_records):.2f}ms")
    print(f"Time Standard Deviation: {statistics.stdev(time_records):.2f}ms")
    
    # 输出总体统计
    print("\nFinal Statistics:")
    print(f"Total Images Processed: {total_images}")
    print(f"Total Predictions Made: {total_predictions}")
    
    if total_predictions > 0:
        overall_accuracy = total_correct / total_predictions
        print(f"Overall Accuracy: {overall_accuracy:.2%}")
    else:
        print("No valid predictions made for accuracy calculation")

    if total_images > 0:
        detection_rate = total_predictions / total_images
        print(f"Detection Rate: {detection_rate:.2f} predictions per image")
# Out:
# Loading model...
# Input shape: [1,256,256,3]
# Output shape: [1,4032,7]
# Starting inference and accuracy calculation...
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([24, 7])
# 69uav2.png
#   Inference Time: 595.20ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([48, 7])
# 57uav3.png
#   Inference Time: 121.32ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([27, 7])
# 75uav2.png
#   Inference Time: 112.86ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([15, 7])
# 73uav2.png
#   Inference Time: 115.97ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([41, 7])
# 23uav3.png
#   Inference Time: 117.29ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 70uav1.png
#   Inference Time: 116.95ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 24uav1.png
#   Inference Time: 113.88ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 64uav1.png
#   Inference Time: 115.91ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 24uav2.png
#   Inference Time: 116.42ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([30, 7])
# 70uav2.png
#   Inference Time: 116.86ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 26uav1.png
#   Inference Time: 113.51ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([34, 7])
# 20uav1.png
#   Inference Time: 115.86ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([40, 7])
# 77uav3.png
#   Inference Time: 114.02ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 71uav1.png
#   Inference Time: 115.53ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 58uav1.png
#   Inference Time: 113.83ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([24, 7])
# 77uav2.png
#   Inference Time: 115.72ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([27, 7])
# 65uav2.png
#   Inference Time: 114.03ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([54, 7])
# 68uav3.png
#   Inference Time: 116.04ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([19, 7])
# 25uav1.png
#   Inference Time: 113.57ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([39, 7])
# 71uav2.png
#   Inference Time: 115.36ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([22, 7])
# 68uav2.png
#   Inference Time: 116.99ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([6, 7])
# 22uav3.png
#   Inference Time: 138.39ms
#   Predicted: {1} | True: {0}
#   Image Accuracy: 0.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([23, 7])
# 19uav3.png
#   Inference Time: 114.75ms
#   Predicted: {0} | True: {0}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([31, 7])
# 19uav2.png
#   Inference Time: 116.87ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([24, 7])
# 29uav2.png
#   Inference Time: 113.47ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([24, 7])
# 28uav2.png
#   Inference Time: 121.07ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([21, 7])
# 21uav2.png
#   Inference Time: 112.61ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([19, 7])
# 18uav2.png
#   Inference Time: 116.75ms
#   Predicted: {0, 1} | True: {0}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([16, 7])
# 78uav1.png
#   Inference Time: 113.47ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([23, 7])
# 74uav1.png
#   Inference Time: 116.09ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([26, 7])
# 57uav2.png
#   Inference Time: 113.84ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([35, 7])
# 60uav3.png
#   Inference Time: 117.27ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([27, 7])
# 19uav1.png
#   Inference Time: 113.53ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([13, 7])
# 61uav2.png
#   Inference Time: 116.49ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 78uav2.png
#   Inference Time: 113.91ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([18, 7])
# 76uav1.png
#   Inference Time: 115.79ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([22, 7])
# 25uav2.png
#   Inference Time: 113.91ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([32, 7])
# 59uav3.png
#   Inference Time: 115.82ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([50, 7])
# 30uav3.png
#   Inference Time: 113.92ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([22, 7])
# 25uav3.png
#   Inference Time: 115.83ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([21, 7])
# 58uav2.png
#   Inference Time: 114.66ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([21, 7])
# 18uav1.png
#   Inference Time: 118.09ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([50, 7])
# 78uav3.png
#   Inference Time: 118.98ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 61uav1.png
#   Inference Time: 117.45ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([21, 7])
# 27uav1.png
#   Inference Time: 112.85ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([41, 7])
# 61uav3.png
#   Inference Time: 115.48ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([31, 7])
# 66uav3.png
#   Inference Time: 112.88ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([25, 7])
# 60uav1.png
#   Inference Time: 115.45ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 60uav2.png
#   Inference Time: 112.70ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([19, 7])
# 23uav1.png
#   Inference Time: 116.24ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([34, 7])
# 21uav1.png
#   Inference Time: 112.96ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([18, 7])
# 27uav2.png
#   Inference Time: 116.41ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([23, 7])
# 67uav3.png
#   Inference Time: 112.88ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([36, 7])
# 72uav3.png
#   Inference Time: 116.51ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([27, 7])
# 26uav3.png
#   Inference Time: 113.55ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([33, 7])
# 31uav3.png
#   Inference Time: 116.29ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([30, 7])
# 22uav2.png
#   Inference Time: 113.09ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([21, 7])
# 63uav1.png
#   Inference Time: 116.39ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([0, 7])
# 18uav3.png
#   Inference Time: 113.18ms
#   Predicted: set() | True: {0}
#   Image Accuracy: 0.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([16, 7])
# 72uav2.png
#   Inference Time: 120.70ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 77uav1.png
#   Inference Time: 114.62ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([42, 7])
# 71uav3.png
#   Inference Time: 115.07ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([19, 7])
# 72uav1.png
#   Inference Time: 113.01ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([14, 7])
# 21uav3.png
#   Inference Time: 116.51ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([52, 7])
# 27uav3.png
#   Inference Time: 112.87ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([41, 7])
# 20uav2.png
#   Inference Time: 120.17ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([24, 7])
# 29uav1.png
#   Inference Time: 114.27ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 30uav1.png
#   Inference Time: 114.80ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 59uav1.png
#   Inference Time: 114.91ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([43, 7])
# 74uav3.png
#   Inference Time: 115.11ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([31, 7])
# 62uav3.png
#   Inference Time: 113.41ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([45, 7])
# 63uav3.png
#   Inference Time: 116.35ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([28, 7])
# 24uav3.png
#   Inference Time: 113.35ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([34, 7])
# 65uav3.png
#   Inference Time: 116.84ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 75uav1.png
#   Inference Time: 113.17ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([18, 7])
# 79uav2.png
#   Inference Time: 116.62ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([31, 7])
# 65uav1.png
#   Inference Time: 120.49ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([1, 7])
# 17uav2.png
#   Inference Time: 117.04ms
#   Predicted: {0} | True: {0}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([16, 7])
# 30uav2.png
#   Inference Time: 114.10ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([21, 7])
# 23uav2.png
#   Inference Time: 114.84ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([33, 7])
# 26uav2.png
#   Inference Time: 115.26ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 57uav1.png
#   Inference Time: 115.57ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 62uav1.png
#   Inference Time: 113.26ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([51, 7])
# 70uav3.png
#   Inference Time: 115.46ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([28, 7])
# 62uav2.png
#   Inference Time: 112.96ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([0, 7])
# 17uav1.png
#   Inference Time: 118.34ms
#   Predicted: set() | True: {0}
#   Image Accuracy: 0.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([24, 7])
# 74uav2.png
#   Inference Time: 114.06ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 28uav1.png
#   Inference Time: 131.09ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([37, 7])
# 29uav3.png
#   Inference Time: 114.99ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([39, 7])
# 28uav3.png
#   Inference Time: 117.04ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 64uav2.png
#   Inference Time: 114.26ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([23, 7])
# 75uav3.png
#   Inference Time: 116.65ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 67uav1.png
#   Inference Time: 113.83ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([22, 7])
# 73uav1.png
#   Inference Time: 123.20ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([29, 7])
# 58uav3.png
#   Inference Time: 115.38ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([59, 7])
# 73uav3.png
#   Inference Time: 119.63ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([42, 7])
# 79uav3.png
#   Inference Time: 113.63ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([53, 7])
# 64uav3.png
#   Inference Time: 115.30ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([21, 7])
# 63uav2.png
#   Inference Time: 114.04ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 76uav2.png
#   Inference Time: 116.44ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([11, 7])
# 20uav3.png
#   Inference Time: 114.20ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([59, 7])
# 69uav3.png
#   Inference Time: 115.55ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 68uav1.png
#   Inference Time: 114.35ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([27, 7])
# 66uav2.png
#   Inference Time: 115.29ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([21, 7])
# 69uav1.png
#   Inference Time: 120.52ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([17, 7])
# 67uav2.png
#   Inference Time: 133.20ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([22, 7])
# 31uav1.png
#   Inference Time: 112.44ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 59uav2.png
#   Inference Time: 115.21ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([34, 7])
# 22uav1.png
#   Inference Time: 113.19ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([20, 7])
# 31uav2.png
#   Inference Time: 116.44ms
#   Predicted: {0, 1} | True: {0, 1}
#   Image Accuracy: 100.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([37, 7])
# 76uav3.png
#   Inference Time: 119.01ms
#   Predicted: {0, 1} | True: set()
#   Image Accuracy: 0.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([22, 7])
# 66uav1.png
#   Inference Time: 114.92ms
#   Predicted: {1} | True: {0, 1}
#   Image Accuracy: 50.00%
# Original Image Size: (144, 256, 3)
# Prediction shape: torch.Size([1, 4032, 7])
# ---x shape---: torch.Size([22, 7])
# 79uav1.png
#   Inference Time: 114.81ms
#   Predicted: {1} | True: {1}
#   Image Accuracy: 100.00%
#
# Time Statistics:
# Total Images Processed: 113
# Total Inference Time: 14194.48ms
# Average Time per Image: 120.22ms
# Fastest Inference: 112.44ms
# Slowest Inference: 595.20ms
# Time Standard Deviation: 45.24ms
#
# Final Statistics:
# Total Images Processed: 113
# Total Predictions Made: 156
# Overall Accuracy: 81.41%
# Detection Rate: 1.38 predictions per image
